# %% [markdown]
# <a href="https://colab.research.google.com/github/prekshith1ju/NLP/blob/main/NLP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('/content/twitter4000.csv')

# %%
data
# Out:
#                                                  twitts  sentiment
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
# [4000 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   twitts     4000 non-null   object
#  1   sentiment  4000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 62.6+ KB

# %%
data.count()
# Out:
# twitts       4000
# sentiment    4000
# dtype: int64

# %%
data['sentiment'].value_counts()
# Out:
# sentiment
# 0    2000
# 1    2000
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0

# %%
data.tail()
# Out:
#                                                  twitts  sentiment
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1

# %%
pattern = r'\s'
data['twitts'].apply(lambda x: re.sub(pattern, '', x))
# Out:
# 0             isboredandwantstowatchamovieanysuggestions?
# 1                        backinmiami.waitingtounboardship
# 2       @misskpeyawwwwdntdisbrngbakmemoriessss,IthnkI'...
# 3                             ughhhiamsotiredblahhhhhhhhh
# 4       @mandagoforthmebad!It'sfunnythough.ZacharyQuin...
#                               ...
# 3995                                       ijustgraduated
# 3996                     Templatingworks;itallhastobedone
# 3997                          mommyjustbroughtmestarbucks
# 3998        @omareppswatchingyouonaHousere-run...lovinit.
# 3999    ThanksfortryingtomakemesmileI'llmakeyour18thsp...
# Name: twitts, Length: 4000, dtype: object

# %%
pattern = r'\s'
data['char_count']= data['twitts'].apply(lambda x: len(re.sub(pattern, '', x)))

# %%
data
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#                                              cahr_count  char_count
# 0           isboredandwantstowatchamovieanysuggestions?          43
# 1                      backinmiami.waitingtounboardship          32
# 2     @misskpeyawwwwdntdisbrngbakmemoriessss,IthnkI'...          54
# 3                           ughhhiamsotiredblahhhhhhhhh          27
# 4     @mandagoforthmebad!It'sfunnythough.ZacharyQuin...         116
# ...                                                 ...         ...
# 3995                                     ijustgraduated          14
# 3996                   Templatingworks;itallhastobedone          32
# 3997                        mommyjustbroughtmestarbucks          27
# 3998      @omareppswatchingyouonaHousere-run...lovinit.          45
# 3999  ThanksfortryingtomakemesmileI'llmakeyour18thsp...          63
#
# [4000 rows x 4 columns]

# %%
data['word_count']= data['twitts'].apply(lambda x: len(x.split()))

# %%
data
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#                                              cahr_count  char_count  \
# 0           isboredandwantstowatchamovieanysuggestions?          43
# 1                      backinmiami.waitingtounboardship          32
# 2     @misskpeyawwwwdntdisbrngbakmemoriessss,IthnkI'...          54
# 3                           ughhhiamsotiredblahhhhhhhhh          27
# 4     @mandagoforthmebad!It'sfunnythough.ZacharyQuin...         116
# ...                                                 ...         ...
# 3995                                     ijustgraduated          14
# 3996                   Templatingworks;itallhastobedone          32
# 3997                        mommyjustbroughtmestarbucks          27
# 3998      @omareppswatchingyouonaHousere-run...lovinit.          45
# 3999  ThanksfortryingtomakemesmileI'llmakeyour18thsp...          63
#
#       word_count
# 0             10
# 1              7
# 2             12
# 3              6
# 4             26
# ...          ...
# 3995           3
# 3996           8
# 3997           5
# 3998           8
# 3999          16
#
# [4000 rows x 5 columns]

# %%
data['avg_word_length']=data['char_count']/data['word_count']

# %%
data
# Out:
#                                                  twitts  sentiment  \
# 0     is bored and wants to watch a movie  any sugge...          0
# 1              back in miami.  waiting to unboard ship           0
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                     ughhh i am so tired  blahhhhhhhhh          0
# 4     @mandagoforth me bad! It's funny though. Zacha...          0
# ...                                                 ...        ...
# 3995                                  i just graduated           1
# 3996          Templating works; it all has to be done            1
# 3997                   mommy just brought me starbucks           1
# 3998  @omarepps watching you on a House re-run...lov...          1
# 3999  Thanks for trying to make me smile I'll make y...          1
#
#                                              cahr_count  char_count  \
# 0           isboredandwantstowatchamovieanysuggestions?          43
# 1                      backinmiami.waitingtounboardship          32
# 2     @misskpeyawwwwdntdisbrngbakmemoriessss,IthnkI'...          54
# 3                           ughhhiamsotiredblahhhhhhhhh          27
# 4     @mandagoforthmebad!It'sfunnythough.ZacharyQuin...         116
# ...                                                 ...         ...
# 3995                                     ijustgraduated          14
# 3996                   Templatingworks;itallhastobedone          32
# 3997                        mommyjustbroughtmestarbucks          27
# 3998      @omareppswatchingyouonaHousere-run...lovinit.          45
# 3999  ThanksfortryingtomakemesmileI'llmakeyour18thsp...          63
#
#       word_count  avg_word_length
# 0             10         4.300000
# 1              7         4.571429
# 2             12         4.500000
# 3              6         4.500000
# 4             26         4.461538
# ...          ...              ...
# 3995           3         4.666667
# 3996           8         4.000000
# 3997           5         5.400000
# 3998           8         5.625000
# 3999          16         3.937500
#
# [4000 rows x 6 columns]
