# %% [markdown]
# <a href="https://colab.research.google.com/github/prekshith1ju/NLP/blob/main/NLP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
# !python -m spacy download en_core_web_sm
nlp = spacy.load('en_core_web_sm')
text = "Unlike fixed-distance races whose winner is determined by minimum time, the 24 Hours of Le Mans is won by the car that covers the greatest distance in 24 hours. The cars on this track are able to achieve speeds of 366 km/h (227 mph), and reached 407 km/h (253 mph) on the Mulsanne Straight in 1988 – instigating the addition of more chicanes to the track to reduce speed reached. Racing teams must balance the demands of speed with the cars' ability to run for 24 hours without mechanical failure.[5] The race is organized by the Automobile Club de l'Ouest (ACO). It is held on the Circuit de la Sarthe, composed of closed public roads and dedicated sections of a racing track."
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
doc = nlp(text)
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Unlike', 'fixed', '-', 'distance', 'races', 'whose', 'winner', 'is', 'determined', 'by', 'minimum', 'time', ',', 'the', '24', 'Hours', 'of', 'Le', 'Mans', 'is', 'won', 'by', 'the', 'car', 'that', 'covers', 'the', 'greatest', 'distance', 'in', '24', 'hours', '.', 'The', 'cars', 'on', 'this', 'track', 'are', 'able', 'to', 'achieve', 'speeds', 'of', '366', 'km', '/', 'h', '(', '227', 'mph', ')', ',', 'and', 'reached', '407', 'km', '/', 'h', '(', '253', 'mph', ')', 'on', 'the', 'Mulsanne', 'Straight', 'in', '1988', '–', 'instigating', 'the', 'addition', 'of', 'more', 'chicanes', 'to', 'the', 'track', 'to', 'reduce', 'speed', 'reached', '.', 'Racing', 'teams', 'must', 'balance', 'the', 'demands', 'of', 'speed', 'with', 'the', 'cars', "'", 'ability', 'to', 'run', 'for', '24', 'hours', 'without', 'mechanical', 'failure.[5', ']', 'The', 'race', 'is', 'organized', 'by', 'the', 'Automobile', 'Club', 'de', "l'Ouest", '(', 'ACO', ')', '.', 'It', 'is', 'held', 'on', 'the', 'Circuit', 'de', 'la', 'Sarthe', ',', 'composed', 'of', 'closed', 'public', 'roads', 'and', 'dedicated', 'sections', 'of', 'a', 'racing', 'track', '.']

# %%
lemmas = [token.lemma_ for token in doc]
print(lemmas)
# Out:
# ['unlike', 'fix', '-', 'distance', 'race', 'whose', 'winner', 'be', 'determine', 'by', 'minimum', 'time', ',', 'the', '24', 'hour', 'of', 'Le', 'Mans', 'be', 'win', 'by', 'the', 'car', 'that', 'cover', 'the', 'great', 'distance', 'in', '24', 'hour', '.', 'the', 'car', 'on', 'this', 'track', 'be', 'able', 'to', 'achieve', 'speed', 'of', '366', 'km', '/', 'h', '(', '227', 'mph', ')', ',', 'and', 'reach', '407', 'km', '/', 'h', '(', '253', 'mph', ')', 'on', 'the', 'Mulsanne', 'Straight', 'in', '1988', '–', 'instigate', 'the', 'addition', 'of', 'more', 'chicane', 'to', 'the', 'track', 'to', 'reduce', 'speed', 'reach', '.', 'race', 'team', 'must', 'balance', 'the', 'demand', 'of', 'speed', 'with', 'the', 'car', "'", 'ability', 'to', 'run', 'for', '24', 'hour', 'without', 'mechanical', 'failure.[5', ']', 'the', 'race', 'be', 'organize', 'by', 'the', 'Automobile', 'Club', 'de', "l'Ouest", '(', 'ACO', ')', '.', 'it', 'be', 'hold', 'on', 'the', 'Circuit', 'de', 'la', 'Sarthe', ',', 'compose', 'of', 'close', 'public', 'road', 'and', 'dedicated', 'section', 'of', 'a', 'racing', 'track', '.']

# %%
pos_tags = [(token.text, token.pos_) for token in doc]
print(pos_tags)
# Out:
# [('Unlike', 'ADP'), ('fixed', 'VERB'), ('-', 'PUNCT'), ('distance', 'NOUN'), ('races', 'NOUN'), ('whose', 'DET'), ('winner', 'NOUN'), ('is', 'AUX'), ('determined', 'VERB'), ('by', 'ADP'), ('minimum', 'ADJ'), ('time', 'NOUN'), (',', 'PUNCT'), ('the', 'DET'), ('24', 'NUM'), ('Hours', 'NOUN'), ('of', 'ADP'), ('Le', 'PROPN'), ('Mans', 'PROPN'), ('is', 'AUX'), ('won', 'VERB'), ('by', 'ADP'), ('the', 'DET'), ('car', 'NOUN'), ('that', 'PRON'), ('covers', 'VERB'), ('the', 'DET'), ('greatest', 'ADJ'), ('distance', 'NOUN'), ('in', 'ADP'), ('24', 'NUM'), ('hours', 'NOUN'), ('.', 'PUNCT'), ('The', 'DET'), ('cars', 'NOUN'), ('on', 'ADP'), ('this', 'DET'), ('track', 'NOUN'), ('are', 'AUX'), ('able', 'ADJ'), ('to', 'PART'), ('achieve', 'VERB'), ('speeds', 'NOUN'), ('of', 'ADP'), ('366', 'NUM'), ('km', 'NOUN'), ('/', 'SYM'), ('h', 'NOUN'), ('(', 'PUNCT'), ('227', 'NUM'), ('mph', 'NOUN'), (')', 'PUNCT'), (',', 'PUNCT'), ('and', 'CCONJ'), ('reached', 'VERB'), ('407', 'NUM'), ('km', 'NOUN'), ('/', 'SYM'), ('h', 'NOUN'), ('(', 'PUNCT'), ('253', 'NUM'), ('mph', 'NOUN'), (')', 'PUNCT'), ('on', 'ADP'), ('the', 'DET'), ('Mulsanne', 'PROPN'), ('Straight', 'PROPN'), ('in', 'ADP'), ('1988', 'NUM'), ('–', 'PUNCT'), ('instigating', 'VERB'), ('the', 'DET'), ('addition', 'NOUN'), ('of', 'ADP'), ('more', 'ADJ'), ('chicanes', 'NOUN'), ('to', 'ADP'), ('the', 'DET'), ('track', 'NOUN'), ('to', 'PART'), ('reduce', 'VERB'), ('speed', 'NOUN'), ('reached', 'VERB'), ('.', 'PUNCT'), ('Racing', 'VERB'), ('teams', 'NOUN'), ('must', 'AUX'), ('balance', 'VERB'), ('the', 'DET'), ('demands', 'NOUN'), ('of', 'ADP'), ('speed', 'NOUN'), ('with', 'ADP'), ('the', 'DET'), ('cars', 'NOUN'), ("'", 'PART'), ('ability', 'NOUN'), ('to', 'PART'), ('run', 'VERB'), ('for', 'ADP'), ('24', 'NUM'), ('hours', 'NOUN'), ('without', 'ADP'), ('mechanical', 'ADJ'), ('failure.[5', 'NOUN'), (']', 'PUNCT'), ('The', 'DET'), ('race', 'NOUN'), ('is', 'AUX'), ('organized', 'VERB'), ('by', 'ADP'), ('the', 'DET'), ('Automobile', 'PROPN'), ('Club', 'PROPN'), ('de', 'ADP'), ("l'Ouest", 'PROPN'), ('(', 'PUNCT'), ('ACO', 'PROPN'), (')', 'PUNCT'), ('.', 'PUNCT'), ('It', 'PRON'), ('is', 'AUX'), ('held', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('Circuit', 'PROPN'), ('de', 'PROPN'), ('la', 'PROPN'), ('Sarthe', 'PROPN'), (',', 'PUNCT'), ('composed', 'VERB'), ('of', 'ADP'), ('closed', 'VERB'), ('public', 'ADJ'), ('roads', 'NOUN'), ('and', 'CCONJ'), ('dedicated', 'ADJ'), ('sections', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('racing', 'NOUN'), ('track', 'NOUN'), ('.', 'PUNCT')]

# %%
entities = [(ent.text, ent.label_) for ent in doc.ents]
print(entities)
# Out:
# [('the 24 Hours', 'TIME'), ('Le Mans', 'ORG'), ('24 hours', 'TIME'), ('366 km/h', 'QUANTITY'), ('227 mph', 'QUANTITY'), ('407 km/h', 'QUANTITY'), ('253 mph', 'QUANTITY'), ('the Mulsanne Straight', 'ORG'), ('1988', 'DATE'), ('24 hours', 'TIME'), ("the Automobile Club de l'Ouest", 'ORG'), ('ACO', 'ORG'), ('the Circuit de la Sarthe', 'ORG')]

# %%
filtered_tokens = [token.text for token in doc if not token.is_stop]
print( filtered_tokens)
# Out:
# ['Unlike', 'fixed', '-', 'distance', 'races', 'winner', 'determined', 'minimum', 'time', ',', '24', 'Hours', 'Le', 'Mans', 'won', 'car', 'covers', 'greatest', 'distance', '24', 'hours', '.', 'cars', 'track', 'able', 'achieve', 'speeds', '366', 'km', '/', 'h', '(', '227', 'mph', ')', ',', 'reached', '407', 'km', '/', 'h', '(', '253', 'mph', ')', 'Mulsanne', 'Straight', '1988', '–', 'instigating', 'addition', 'chicanes', 'track', 'reduce', 'speed', 'reached', '.', 'Racing', 'teams', 'balance', 'demands', 'speed', 'cars', "'", 'ability', 'run', '24', 'hours', 'mechanical', 'failure.[5', ']', 'race', 'organized', 'Automobile', 'Club', 'de', "l'Ouest", '(', 'ACO', ')', '.', 'held', 'Circuit', 'de', 'la', 'Sarthe', ',', 'composed', 'closed', 'public', 'roads', 'dedicated', 'sections', 'racing', 'track', '.']

# %%
import nltk
from nltk.stem import PorterStemmer
nltk.download('wordnet')
nltk.download('punkt')

stemmer = PorterStemmer()

stemmed_tokens = [stemmer.stem(token) for token in tokens]
print(stemmed_tokens)
# Out:
# ['unlik', 'fix', '-', 'distanc', 'race', 'whose', 'winner', 'is', 'determin', 'by', 'minimum', 'time', ',', 'the', '24', 'hour', 'of', 'le', 'man', 'is', 'won', 'by', 'the', 'car', 'that', 'cover', 'the', 'greatest', 'distanc', 'in', '24', 'hour', '.', 'the', 'car', 'on', 'thi', 'track', 'are', 'abl', 'to', 'achiev', 'speed', 'of', '366', 'km', '/', 'h', '(', '227', 'mph', ')', ',', 'and', 'reach', '407', 'km', '/', 'h', '(', '253', 'mph', ')', 'on', 'the', 'mulsann', 'straight', 'in', '1988', '–', 'instig', 'the', 'addit', 'of', 'more', 'chican', 'to', 'the', 'track', 'to', 'reduc', 'speed', 'reach', '.', 'race', 'team', 'must', 'balanc', 'the', 'demand', 'of', 'speed', 'with', 'the', 'car', "'", 'abil', 'to', 'run', 'for', '24', 'hour', 'without', 'mechan', 'failure.[5', ']', 'the', 'race', 'is', 'organ', 'by', 'the', 'automobil', 'club', 'de', "l'ouest", '(', 'aco', ')', '.', 'it', 'is', 'held', 'on', 'the', 'circuit', 'de', 'la', 'sarth', ',', 'compos', 'of', 'close', 'public', 'road', 'and', 'dedic', 'section', 'of', 'a', 'race', 'track', '.']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
